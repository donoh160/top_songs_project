# %%
import billboard
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import base64
from requests import post, get
import json
import time
from datetime import datetime, timedelta

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
data_df = pd.read_csv("data_df.csv")

# Display sample data
data_df.head()
# Out:
#                             Song Name                    Artist  \
# 0                             Bad Day             Daniel Powter
# 1                         Temperature                 Sean Paul
# 2                         Promiscuous  Nelly Furtado, Timbaland
# 3                    You're Beautiful               James Blunt
# 4  Hips Don't Lie (feat. Wyclef Jean)      Shakira, Wyclef Jean
#
#                Spotify ID            Genres Duration  Popularity Release Date
# 0  0mUyMawtxj1CJ76kn9gIZK               NaN     3:53          71   2005-02-22
# 1  0k2GOhqsrxDTAbFFSdNJjT         dancehall     3:38          78   2005-09-27
# 2  2gam98EZKrF9XuOkU13ApN               NaN     4:02          83   2006-01-01
# 3  0vg4WnUWvze6pBOJDTq99k               NaN     3:29          73   2005-08-08
# 4  3ZFTkvIE7kyPt6Nu3PEa7V  latin pop, latin     3:38          84   2005-11-28

# %%
data_df["Year"] = ""
data_df.head()
# Out:
#                             Song Name                    Artist  \
# 0                             Bad Day             Daniel Powter
# 1                         Temperature                 Sean Paul
# 2                         Promiscuous  Nelly Furtado, Timbaland
# 3                    You're Beautiful               James Blunt
# 4  Hips Don't Lie (feat. Wyclef Jean)      Shakira, Wyclef Jean
#
#                Spotify ID            Genres Duration  Popularity Release Date  \
# 0  0mUyMawtxj1CJ76kn9gIZK               NaN     3:53          71   2005-02-22
# 1  0k2GOhqsrxDTAbFFSdNJjT         dancehall     3:38          78   2005-09-27
# 2  2gam98EZKrF9XuOkU13ApN               NaN     4:02          83   2006-01-01
# 3  0vg4WnUWvze6pBOJDTq99k               NaN     3:29          73   2005-08-08
# 4  3ZFTkvIE7kyPt6Nu3PEa7V  latin pop, latin     3:38          84   2005-11-28
#
#   Year
# 0
# 1
# 2
# 3
# 4

# %%
# Convert 'Year' column to numeric values, coercing errors to NaN
data_df['Year'] = pd.to_numeric(data_df['Year'], errors='coerce')

# Fill NaN values (if any) with 0 (or any other placeholder you want)
data_df['Year'].fillna(0, inplace=True)

# Convert 'Year' back to integers after filling NaN
data_df['Year'] = data_df['Year'].astype(int)

# Add 2006 to the 'Year' column for the first 100 rows
data_df.loc[:99, 'Year'] = 2006

# Add 1 to the 'Year' for every subsequent block of 100 rows (e.g., 2007, 2008, etc.)
for i in range(1, (len(data_df) // 100) + 1):
    start_idx = i * 100
    end_idx = (i + 1) * 100
    data_df.loc[start_idx:end_idx - 1, 'Year'] = 2006 + i

# Output the result
print(data_df[['Song Name', 'Year']].head(110))  # Display first 110 rows to check
# Out:
#                               Song Name  Year
# 0                               Bad Day  2006
# 1                           Temperature  2006
# 2                           Promiscuous  2006
# 3                      You're Beautiful  2006
# 4    Hips Don't Lie (feat. Wyclef Jean)  2006
# ..                                  ...   ...
# 105                    Before He Cheats  2007
# 106                   Hey There Delilah  2007
# 107                    I Wanna Love You  2007
# 108                        Say It Right  2007
# 109                           Glamorous  2007
#
# [110 rows x 2 columns]
# C:\Users\duvoe\AppData\Local\Temp\ipykernel_4588\2953739787.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['Year'].fillna(0, inplace=True)

# %%
data_df.head(1900)
# Out:
#                                Song Name                       Artist  \
# 0                                Bad Day                Daniel Powter
# 1                            Temperature                    Sean Paul
# 2                            Promiscuous     Nelly Furtado, Timbaland
# 3                       You're Beautiful                  James Blunt
# 4     Hips Don't Lie (feat. Wyclef Jean)         Shakira, Wyclef Jean
# ...                                  ...                          ...
# 1895                         Bulletproof                      La Roux
# 1896          FE!N (feat. Playboi Carti)  Travis Scott, Playboi Carti
# 1897                         The Painter                 Cody Johnson
# 1898                            Down Bad                 Taylor Swift
# 1899                     Dance The Night                     Dua Lipa
#
#                   Spotify ID                            Genres Duration  \
# 0     0mUyMawtxj1CJ76kn9gIZK                               NaN     3:53
# 1     0k2GOhqsrxDTAbFFSdNJjT                         dancehall     3:38
# 2     2gam98EZKrF9XuOkU13ApN                               NaN     4:02
# 3     0vg4WnUWvze6pBOJDTq99k                               NaN     3:29
# 4     3ZFTkvIE7kyPt6Nu3PEa7V                  latin pop, latin     3:38
# ...                      ...                               ...      ...
# 1895  3kMrazSvILsgcwtidZd1Qd                               NaN     3:25
# 1896  3KEMjT3QVfKIl4E9DIcrmF                               rap     3:11
# 1897  6UoKX6uLJwhsnyTp5k5StP  texas country, country, red dirt     3:31
# 1898  5O4SPACkaBSKjBJEPYJwfQ                               NaN     4:21
# 1899  11C4y2Yz1XbHmaQwO06s9f                               pop     2:56
#
#       Popularity Release Date  Year
# 0             71   2005-02-22  2006
# 1             78   2005-09-27  2006
# 2             83   2006-01-01  2006
# 3             73   2005-08-08  2006
# 4             84   2005-11-28  2006
# ...          ...          ...   ...
# 1895          71         2009  2024
# 1896          70   2023-07-26  2024
# 1897          64   2023-08-11  2024
# 1898          50   2024-04-19  2024
# 1899          67   2023-07-21  2024
#
# [1900 rows x 8 columns]

# %%
data_df.drop('Release Date', axis=1, inplace=True)
data_df.head()
# Out:
#                             Song Name                    Artist  \
# 0                             Bad Day             Daniel Powter
# 1                         Temperature                 Sean Paul
# 2                         Promiscuous  Nelly Furtado, Timbaland
# 3                    You're Beautiful               James Blunt
# 4  Hips Don't Lie (feat. Wyclef Jean)      Shakira, Wyclef Jean
#
#                Spotify ID            Genres Duration  Popularity  Year
# 0  0mUyMawtxj1CJ76kn9gIZK               NaN     3:53          71  2006
# 1  0k2GOhqsrxDTAbFFSdNJjT         dancehall     3:38          78  2006
# 2  2gam98EZKrF9XuOkU13ApN               NaN     4:02          83  2006
# 3  0vg4WnUWvze6pBOJDTq99k               NaN     3:29          73  2006
# 4  3ZFTkvIE7kyPt6Nu3PEa7V  latin pop, latin     3:38          84  2006

# %%
data_df['Rank'] = (data_df.index % 100) + 1
data_df.head(101)
# Out:
#                               Song Name                    Artist  \
# 0                               Bad Day             Daniel Powter
# 1                           Temperature                 Sean Paul
# 2                           Promiscuous  Nelly Furtado, Timbaland
# 3                      You're Beautiful               James Blunt
# 4    Hips Don't Lie (feat. Wyclef Jean)      Shakira, Wyclef Jean
# ..                                  ...                       ...
# 96                       Feel Good Inc.                  Gorillaz
# 97                           I'm Sprung                    T-Pain
# 98                  Do I Make You Proud              Taylor Hicks
# 99          For You I Will (Confidence)             Kidz Bop Kids
# 100                       Irreplaceable                   Beyoncé
#
#                  Spotify ID            Genres Duration  Popularity  Year  Rank
# 0    0mUyMawtxj1CJ76kn9gIZK               NaN     3:53          71  2006     1
# 1    0k2GOhqsrxDTAbFFSdNJjT         dancehall     3:38          78  2006     2
# 2    2gam98EZKrF9XuOkU13ApN               NaN     4:02          83  2006     3
# 3    0vg4WnUWvze6pBOJDTq99k               NaN     3:29          73  2006     4
# 4    3ZFTkvIE7kyPt6Nu3PEa7V  latin pop, latin     3:38          84  2006     5
# ..                      ...               ...      ...         ...   ...   ...
# 96   0d28khcov6AiegSCpG5TuT               NaN     3:42          85  2006    97
# 97   0DLOyyQvwPTSDKuhpzMMwA               NaN     3:51          71  2006    98
# 98   2jv9Ppwz9u3lqWfXV0q2sW               NaN     4:08          22  2006    99
# 99   43q9QXWgnB6b4qRq60CO0N  children's music     3:50           2  2006   100
# 100  6RX5iL93VZ5fKmyvNXvF1r               NaN     3:47          70  2007     1
#
# [101 rows x 8 columns]

# %%
data_df.rename(columns={'Song Name': 'Title'}, inplace=True)

# %%
new_df = data_df[['Year', 'Rank', 'Title', 'Artist', 'Spotify ID', 'Genres', 'Duration', 'Popularity']]
new_df.head(202)
# Out:
#      Year  Rank                               Title                    Artist  \
# 0    2006     1                             Bad Day             Daniel Powter
# 1    2006     2                         Temperature                 Sean Paul
# 2    2006     3                         Promiscuous  Nelly Furtado, Timbaland
# 3    2006     4                    You're Beautiful               James Blunt
# 4    2006     5  Hips Don't Lie (feat. Wyclef Jean)      Shakira, Wyclef Jean
# ..    ...   ...                                 ...                       ...
# 197  2007    98                           Paralyzer             Finger Eleven
# 198  2007    99                         That's That                 lou deezi
# 199  2007   100              Same Girl (with Usher)           R. Kelly, USHER
# 200  2008     1                  Low (feat. T-Pain)          Flo Rida, T-Pain
# 201  2008     2                       Bleeding Love               Leona Lewis
#
#                  Spotify ID            Genres Duration  Popularity
# 0    0mUyMawtxj1CJ76kn9gIZK               NaN     3:53          71
# 1    0k2GOhqsrxDTAbFFSdNJjT         dancehall     3:38          78
# 2    2gam98EZKrF9XuOkU13ApN               NaN     4:02          83
# 3    0vg4WnUWvze6pBOJDTq99k               NaN     3:29          73
# 4    3ZFTkvIE7kyPt6Nu3PEa7V  latin pop, latin     3:38          84
# ..                      ...               ...      ...         ...
# 197  28IEbk5a7twNTbUEvWslUb               NaN     3:28          74
# 198  08ZPPS44d64Vv7HnCy96a2               NaN     2:29          55
# 199  6OSmeoh8kXhCfz9WqvzDoJ               r&b     4:12          59
# 200  0CAfXk7DXMnon4gLudAp7J               NaN     3:51          79
# 201  7wZUrN8oemZfsEd1CGkbXE               NaN     4:22          77
#
# [202 rows x 8 columns]

# %%
nan_count = new_df['Genres'].isna().sum()

print(f"Number of NaN values in the 'Genres' column: {nan_count}")
# Out:
# Number of NaN values in the 'Genres' column: 930

# %%
new_df.to_csv('songs_ranked.csv', index=False)
